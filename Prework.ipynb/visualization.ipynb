# %% [markdown]
# Scatter plots

# %%
import numpy as np

x = np.linspace(0, 10, 30)

y = np.sin(x)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(x, y, label= "Function: sin(x)")
plt.title("Scatter plot in matplotlib")
plt.legend()
plt.show()

# %%
plt.figure(figsize= (10,6))
plt.scatter(x, y, label = "Function: sin(x)")

plt.xlabel("X values")
plt.ylabel("Y values")

plt.title("Scater plot in matplotlib")
plt.legend()
plt.show()

# %% [markdown]
# Bar Charts

# %%
np.random.seed(100)

x = np.arange(10)
y = np.random.randn(10)

# %%
plt.figure(figsize=(10,6))
plt.bar(x, y, label= "Sample Data")

plt.xlabel("X value - Categorical")
plt.ylabel("Y value - Quantity")

plt.title("Bar plot in matplotlib")
plt.legend()
plt.show()

# %% [markdown]
# Histogram

# %%
np.random.seed(100)

x = 5*np.random.randn(200) + 65

plt.hist(x, bins = 10, edgecolor= "Black")
plt.xlabel("Retirement Age")
plt.ylabel("Frequency of values")
plt.title("Histogrm in matplotlib")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# The bins argument

# %%
plt.hist(x, bins=5, edgecolor='black')
plt.xlabel('Retirement Age')
plt.ylabel('Frequency of Values')
plt.title('Histograms in Matplotlib')
plt.show()

# %%
# Set seed for reproducability
np.random.seed(100)

# Generate a data set of 10000 retirement age values
x = 5*np.random.randn(10000) + 65

#Plot the distogram with hist() function
plt.hist(x, bins=50, edgecolor="black")

plt.xlabel('Retirement Age')
plt.ylabel('Frequency of Values')
plt.title('Histograms in Matplotlib')
plt.show()

# %% [markdown]
# Exercise 1

# %%
height = [40, 30, 10, 50, 25, 5]
x = range(len(height))
label = ["crime", "science fiction", "drama", "comedy", "action", "documentary"]

fig, ax = plt.subplots(figsize= (8,6))
plt.bar(x, height, tick_label = label )

plt.xlabel("Genre")
plt.ylabel("Number of Movies")

plt.title("Jims Video Library")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# Exercise 2

# %%
weight = [2750, 3125, 2100, 4082, 2690, 3640, 4380, 2241, 2895, 3659]
mpg = [29, 23, 33, 28, 20, 21, 14, 25, 31, 17]

fig, ay= plt.subplots(figsize= (8,6))

plt.scatter(mpg, weight, label= "Weight vs Milage")

plt.xlabel("Miles per Gallon")
plt.ylabel("Weight in kg")

plt.title("Relationship between weight and mpg")
plt.legend()
plt.show()

# %% [markdown]
# Exercise 3

# %%
x = [43.1, 35.6, 37.5, 36.5, 45.3, 43.4, 
     40.3, 50.2, 47.3, 31.2, 42.2, 45.5, 
     30.3, 31.4, 35.6, 45.2, 54.1, 45.6, 
     36.5, 43.1]

fig, ax= plt.subplots(figsize= (8,6))

plt.hist(x, bins= 5, edgecolor= "Black")

plt.xlabel("waiting time")
plt.ylabel("Number of customers")

plt.title("Customer waiting times")
plt.show()
