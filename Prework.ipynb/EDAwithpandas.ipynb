# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#loading the dataset
df = pd.read_csv("D:/Programming/Datasets/ames.csv", index_col=0)

# %%
# Run this cell without changes

# Check that df is a dataframe
assert type(df) == pd.DataFrame

# Check that there are the correct number of rows
assert df.shape[0] == 1460

# Check that there are the correct number of columns
# (if this crashes, make sure you specified `index_col=0`)
assert df.shape[1] == 80

# %%
#inspecting the content of the dataframe
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
#histogram of salesprices
salesprice_mean = df["SalePrice"].mean()
df["SalePrice"].hist(bins=10, edgecolor="black")

#adding a vertical line to the histogram
plt.axvline(salesprice_mean, color="Red", linestyle="dashed", linewidth=2)

#labelling the diagram
plt.xlabel("Sales Prices")
plt.ylabel("Frequency")
plt.title("Number of Sales Prices")
plt.show()

# %%
#mean, median, and standard deviation of Sales Price
df["SalePrice"].agg(["mean", "median", "std"])
# Out:
# mean      180921.195890
# median    163000.000000
# std        79442.502883
# Name: SalePrice, dtype: float64

# %%
#TotRmsAbvGrd histogram
TotRmsAbvGrd_mean = df["TotRmsAbvGrd"].mean()
df["TotRmsAbvGrd"].hist(bins=10, edgecolor="Black")

#adding a vertical mean line to the histogrm
plt.axvline(TotRmsAbvGrd_mean, color="Red", linestyle="dashed", linewidth=2)

#labelling parts of the histogram
plt.xlabel("Total Rooms Above Grade")
plt.ylabel("Frequency")
plt.title("Number of Total Rooms Above Grade")
plt.show()

# %%
#mean, median, and standard deviation of of Total Rooms Above Grade
df["TotRmsAbvGrd"].agg(["mean", "median", "std"])
# Out:
# mean      6.517808
# median    6.000000
# std       1.625393
# Name: TotRmsAbvGrd, dtype: float64

# %%
#OverallCond histogram
overallCond_mean = df["OverallCond"].mean()
df["OverallCond"].hist(bins=10, edgecolor="black")

#creating the vertical mean overallcond line
plt.axvline(overallCond_mean, color= "Red", linestyle="dashed", linewidth=2)

#Labelling axis
plt.xlabel("Overall Condition")
plt.ylabel("Frequency")
plt.title("Number of Overall Condition")
plt.show()

# %%
#mean, median, and standard deviation of overall condition
df["OverallCond"].agg(["mean", "median", "std"])
# Out:
# mean      5.575342
# median    5.000000
# std       1.112799
# Name: OverallCond, dtype: float64

# %%
#In the cell below, create three variables, each of which represents a record-wise subset of df 
# (meaning, it has the same columns as df, but only some of the rows).
below_average_condition = df[df["OverallCond"] < 5]
average_condition = df[df["OverallCond"] == 5]
above_average_condition = df[df["OverallCond"] > 5]

# %%
# Run this cell without changes

# Check that all of them still have 80 columns
assert below_average_condition.shape[1] == 80
assert average_condition.shape[1] == 80
assert above_average_condition.shape[1] == 80

# Check the numbers of rows of each subset
assert below_average_condition.shape[0] == 88
assert average_condition.shape[0] == 821
assert above_average_condition.shape[0] == 551

# %%
# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Create custom bins so all are on the same scale
bins = range(df["SalePrice"].min(), df["SalePrice"].max(), int(df["SalePrice"].median()) // 20)

# Plot three histograms, with reduced opacity (alpha) so we
# can see them overlapping
ax.hist(
    x=above_average_condition["SalePrice"],
    label="above average condition",
    bins=bins,
    color="cyan",
    alpha=0.5
)
ax.hist(
    x=average_condition["SalePrice"],
    label="average condition",
    bins=bins,
    color="gray",
    alpha=0.3
)
ax.hist(
    x=below_average_condition["SalePrice"],
    label="below average condition",
    bins=bins,
    color="yellow",
    alpha=0.5
)

# Customize labels
ax.set_title("Distributions of Sale Price Grouped by Condition")
ax.set_xlabel("Sale Price")
ax.set_ylabel("Number of Houses")
ax.legend();

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
#exploring the most positive correlation
#selecting only numeric columns
numeric_df = df.select_dtypes(include=["number"])

#Computing the Pearson correlation matrix
correlation_matrix = numeric_df.corr()

# Exclude SalePrice correlation with itself and find the column with the highest 
correlation_with_saleprice = correlation_matrix["SalePrice"].drop("SalePrice")

# Get the column with the highest positive correlation
most_positive_corr_column = correlation_with_saleprice.idxmax()
most_positive_corr_value = correlation_with_saleprice.max()

# Print the column name and its correlation value
print(f"Column: {most_positive_corr_column}, Pearson correlation: {most_positive_corr_value}")
# Out:
# Column: OverallQual, Pearson correlation: 0.7909816005838047

# %%
#The most negative correlation value
most_negative_corr_column = correlation_with_saleprice.idxmin()
most_negative_corr_value = correlation_with_saleprice.min()

#Printing the column name and its correlation value
print(f"Column: {most_negative_corr_column}, Pearson value: {most_negative_corr_value}")
# Out:
# Column: KitchenAbvGr, Pearson value: -0.1359073708421417

# %%
# Replace None with appropriate code

import seaborn as sns

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15,5))

# Plot distribution of column with highest correlation
sns.boxplot(
    x=df[most_positive_corr_column],
    y=df["SalePrice"],
    ax=ax1
)
# Plot distribution of column with most negative correlation
sns.boxplot(
    x=df[most_negative_corr_column],
    y=df["SalePrice"],
    ax=ax2
)

# Customize labels
ax1.set_title("Highest correlation")
ax1.set_xlabel("most positve correlation column")
ax1.set_ylabel("Sale Price")
ax2.set_title("Negative correlation")
ax2.set_xlabel("most_negative_corr_column")
ax2.set_ylabel("Sale Price");

# %%
#Engineer and Explore a New Feature
df["YrSold"].value_counts().sort_index()
# Out:
# 2006    314
# 2007    329
# 2008    304
# 2009    338
# 2010    175
# Name: YrSold, dtype: int64

# %%
# Make a new column, Age
df["Age"] = df["YrSold"] - df["YearBuilt"]

# Set up plot
fig, ax = plt.subplots(figsize=(15,5))

# Plot Age vs. SalePrice
ax.scatter(df["Age"], df["SalePrice"], alpha=0.3, color="green")
ax.set_title("Home Age vs. Sale Price")
ax.set_xlabel("Age of Home at Time of Sale")
ax.set_ylabel("Sale Price");
